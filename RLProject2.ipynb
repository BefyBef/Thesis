# %%
import numpy as np
import random
from collections import deque
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input

class TrafficIntersection:
    def __init__(self, lanes):
        self.lanes = lanes
        self.state = self.reset()
        
    def reset(self):
        self.state = [random.randint(0, 100) for _ in range(self.lanes)]
        return self.state
    
    def step(self, actions):
        green_times = [action * 3 for action in actions]
        new_state = []
        rewards = []
        
        for i in range(self.lanes):
            vehicle_left = self.state[i] - green_times[i]
            new_state.append(max(vehicle_left, 0))  
            
            reward = 0
            if vehicle_left == 0:
                reward += 10000
            else:
                reward -= abs(vehicle_left) * 100
            if green_times[i] > self.state[i]:
                reward -= (green_times[i] - self.state[i]) * 100 
            rewards.append(reward)
        
        self.state = new_state
        return new_state, rewards

@tf.keras.utils.register_keras_serializable()
class QNetwork(Model):
    def __init__(self, state_size, action_size, **kwargs):
        super(QNetwork, self).__init__(**kwargs)
        self.state_size = state_size
        self.action_size = action_size
        self.dense1 = Dense(24, activation='relu')
        self.dense2 = Dense(24, activation='relu')
        self.out = Dense(action_size, activation='linear')
    
    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.out(x)
    
    def get_config(self):
        config = super(QNetwork, self).get_config()
        config.update({
            'state_size': self.state_size,
            'action_size': self.action_size,
        })
        return config
    
    @classmethod
    def from_config(cls, config):
        return cls(**config)

class CentralController:
    def __init__(self, agents):
        self.agents = agents
    
    def get_joint_action(self, states):
        actions = []
        for i, agent in enumerate(self.agents):
            state = np.reshape(states[i], [1, 1])
            action = agent.choose_action(state)
            actions.append(action)
        return actions

class DQNAgent:
    def __init__(self, state_size, action_size, gamma, epsilon, epsilon_min, epsilon_decay, learning_rate, batch_size, memory_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=memory_size)
        self.gamma = gamma  
        self.epsilon = epsilon  
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.model(np.zeros((1, self.state_size)))  
        self.target_model(np.zeros((1, self.state_size)))  
        self.update_target_model()
    
    def _build_model(self):
        model = QNetwork(self.state_size, self.action_size)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate),
                      loss='mse')
        return model
    
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())
    
    def remember(self, state, action, reward, next_state):
        self.memory.append((state, action, reward, next_state))
    
    def choose_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state, verbose=0)
        return np.argmax(act_values[0])
    
    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        minibatch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state in minibatch:
            target = self.model.predict(state, verbose=0)
            target_f = self.target_model.predict(next_state, verbose=0)
            target[0][action] = reward + self.gamma * np.amax(target_f[0])
            self.model.fit(state, target, epochs=1, verbose=0)
            
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
    
    def train(self, env, controller, episodes):
        for e in range(episodes):
            state = env.reset()
            done = [False] * env.lanes
            time_step = 0
            print(f"\nTraining Episode {e+1}/{episodes}")
            while not all(done):
                actions = controller.get_joint_action(state)
                next_state, rewards = env.step(actions)
                for i in range(env.lanes):
                    if not done[i]:  # Skip lanes that are already done
                        self.remember(np.reshape(state[i], [1, 1]), actions[i], rewards[i], np.reshape(next_state[i], [1, 1]))
                        print(f"Time Step {time_step+1}, Lane {i+1}, Vehicle Waiting: {state[i]}, Green Time Chosen: {actions[i] * 3} seconds, Vehicle Left: {next_state[i]}, Reward: {rewards[i]}")
                        if next_state[i] == 0:
                            done[i] = True
                state = next_state
                if time_step % 10 == 0:
                    self.replay()
                time_step += 1
            self.update_target_model()
            print(f"Episode {e+1}/{episodes}, Epsilon: {self.epsilon:.2f}")
    
    def predict_green_signal(self, vehicle_count):
        vehicle_count = int(vehicle_count)
        return self.choose_action(np.reshape(vehicle_count, [1, 1])) * 3
    
    def save_model(self, path):
        self.model.save(path)
    
    def load_model(self, path):
        self.model = tf.keras.models.load_model(path)

gamma = 0.95
epsilon = 1.0
epsilon_min = 0.01
epsilon_decay = 0.995
learning_rate = 0.001
batch_size = 32
memory_size = 2000
state_size = 1 
action_size = 11 
lanes = 4
env = TrafficIntersection(lanes)
agents = [DQNAgent(state_size, action_size, gamma, epsilon, epsilon_min, epsilon_decay, learning_rate, batch_size, memory_size) for _ in range(lanes)]
controller = CentralController(agents)

episodes = 500
for agent in agents:
    agent.train(env, controller, episodes)

def test_agents(environment, agents, controller, num_episodes):
    for e in range(num_episodes):
        states = environment.reset()
        done = [False] * environment.lanes
        time_step = 0
        print(f"\nTesting Episode {e+1}/{num_episodes}")
        while not all(done):
            actions = controller.get_joint_action(states)
            next_states, rewards = environment.step(actions)
            
            for lane in range(environment.lanes):
                if not done[lane]:
                    done[lane] = next_states[lane] == 0
                    print(f"Time Step {time_step+1}, Lane {lane+1}, Vehicle Waiting: {states[lane]}, Green Time Chosen: {actions[lane] * 3} seconds, Vehicle Left: {next_states[lane]}, Reward: {rewards[lane]}")
                    states[lane] = next_states[lane]
                    
            time_step += 1

test_episodes = 5
test_agents(env, agents, controller, test_episodes)
# Out:
# Training Episode 1/500
# Time Step 1, Lane 1, Vehicle Waiting: 88, Green Time Chosen: 21 seconds, Vehicle Left: 67, Reward: -6700
# Time Step 1, Lane 2, Vehicle Waiting: 9, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -600
# Time Step 1, Lane 3, Vehicle Waiting: 28, Green Time Chosen: 15 seconds, Vehicle Left: 13, Reward: -1300
# Time Step 1, Lane 4, Vehicle Waiting: 79, Green Time Chosen: 3 seconds, Vehicle Left: 76, Reward: -7600
# Time Step 2, Lane 1, Vehicle Waiting: 67, Green Time Chosen: 27 seconds, Vehicle Left: 40, Reward: -4000
# Time Step 2, Lane 3, Vehicle Waiting: 13, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -1600
# Time Step 2, Lane 4, Vehicle Waiting: 76, Green Time Chosen: 15 seconds, Vehicle Left: 61, Reward: -6100
# Time Step 3, Lane 1, Vehicle Waiting: 40, Green Time Chosen: 6 seconds, Vehicle Left: 34, Reward: -3400
# Time Step 3, Lane 4, Vehicle Waiting: 61, Green Time Chosen: 30 seconds, Vehicle Left: 31, Reward: -3100
# Time Step 4, Lane 1, Vehicle Waiting: 34, Green Time Chosen: 15 seconds, Vehicle Left: 19, Reward: -1900
# Time Step 4, Lane 4, Vehicle Waiting: 31, Green Time Chosen: 12 seconds, Vehicle Left: 19, Reward: -1900
# Time Step 5, Lane 1, Vehicle Waiting: 19, Green Time Chosen: 9 seconds, Vehicle Left: 10, Reward: -1000
# Time Step 5, Lane 4, Vehicle Waiting: 19, Green Time Chosen: 12 seconds, Vehicle Left: 7, Reward: -700
# Time Step 6, Lane 1, Vehicle Waiting: 10, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -2200
# Time Step 6, Lane 4, Vehicle Waiting: 7, Green Time Chosen: 6 seconds, Vehicle Left: 1, Reward: -100
# Time Step 7, Lane 4, Vehicle Waiting: 1, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -3400
# Episode 1/500, Epsilon: 1.00
#
# Training Episode 2/500
# Time Step 1, Lane 1, Vehicle Waiting: 84, Green Time Chosen: 6 seconds, Vehicle Left: 78, Reward: -7800
# Time Step 1, Lane 2, Vehicle Waiting: 90, Green Time Chosen: 30 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 1, Lane 3, Vehicle Waiting: 74, Green Time Chosen: 9 seconds, Vehicle Left: 65, Reward: -6500
# Time Step 1, Lane 4, Vehicle Waiting: 88, Green Time Chosen: 9 seconds, Vehicle Left: 79, Reward: -7900
# Time Step 2, Lane 1, Vehicle Waiting: 78, Green Time Chosen: 30 seconds, Vehicle Left: 48, Reward: -4800
# Time Step 2, Lane 2, Vehicle Waiting: 60, Green Time Chosen: 21 seconds, Vehicle Left: 39, Reward: -3900
# Time Step 2, Lane 3, Vehicle Waiting: 65, Green Time Chosen: 0 seconds, Vehicle Left: 65, Reward: -6500
# Time Step 2, Lane 4, Vehicle Waiting: 79, Green Time Chosen: 6 seconds, Vehicle Left: 73, Reward: -7300
# Time Step 3, Lane 1, Vehicle Waiting: 48, Green Time Chosen: 27 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 3, Lane 2, Vehicle Waiting: 39, Green Time Chosen: 30 seconds, Vehicle Left: 9, Reward: -900
# Time Step 3, Lane 3, Vehicle Waiting: 65, Green Time Chosen: 12 seconds, Vehicle Left: 53, Reward: -5300
# Time Step 3, Lane 4, Vehicle Waiting: 73, Green Time Chosen: 3 seconds, Vehicle Left: 70, Reward: -7000
# Time Step 4, Lane 1, Vehicle Waiting: 21, Green Time Chosen: 9 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 4, Lane 2, Vehicle Waiting: 9, Green Time Chosen: 3 seconds, Vehicle Left: 6, Reward: -600
# Time Step 4, Lane 3, Vehicle Waiting: 53, Green Time Chosen: 9 seconds, Vehicle Left: 44, Reward: -4400
# Time Step 4, Lane 4, Vehicle Waiting: 70, Green Time Chosen: 27 seconds, Vehicle Left: 43, Reward: -4300
# Time Step 5, Lane 1, Vehicle Waiting: 12, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 5, Lane 2, Vehicle Waiting: 6, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4800
# Time Step 5, Lane 3, Vehicle Waiting: 44, Green Time Chosen: 24 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 5, Lane 4, Vehicle Waiting: 43, Green Time Chosen: 3 seconds, Vehicle Left: 40, Reward: -4000
# Time Step 6, Lane 3, Vehicle Waiting: 20, Green Time Chosen: 18 seconds, Vehicle Left: 2, Reward: -200
# Time Step 6, Lane 4, Vehicle Waiting: 40, Green Time Chosen: 21 seconds, Vehicle Left: 19, Reward: -1900
# Time Step 7, Lane 3, Vehicle Waiting: 2, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -2600
# Time Step 7, Lane 4, Vehicle Waiting: 19, Green Time Chosen: 15 seconds, Vehicle Left: 4, Reward: -400
# Time Step 8, Lane 4, Vehicle Waiting: 4, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -2200
# Episode 2/500, Epsilon: 1.00
#
# Training Episode 3/500
# Time Step 1, Lane 1, Vehicle Waiting: 28, Green Time Chosen: 6 seconds, Vehicle Left: 22, Reward: -2200
# Time Step 1, Lane 2, Vehicle Waiting: 74, Green Time Chosen: 6 seconds, Vehicle Left: 68, Reward: -6800
# Time Step 1, Lane 3, Vehicle Waiting: 23, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -200
# Time Step 1, Lane 4, Vehicle Waiting: 95, Green Time Chosen: 21 seconds, Vehicle Left: 74, Reward: -7400
# Time Step 2, Lane 1, Vehicle Waiting: 22, Green Time Chosen: 3 seconds, Vehicle Left: 19, Reward: -1900
# Time Step 2, Lane 2, Vehicle Waiting: 68, Green Time Chosen: 9 seconds, Vehicle Left: 59, Reward: -5900
# Time Step 2, Lane 4, Vehicle Waiting: 74, Green Time Chosen: 0 seconds, Vehicle Left: 74, Reward: -7400
# Time Step 3, Lane 1, Vehicle Waiting: 19, Green Time Chosen: 15 seconds, Vehicle Left: 4, Reward: -400
# Time Step 3, Lane 2, Vehicle Waiting: 59, Green Time Chosen: 12 seconds, Vehicle Left: 47, Reward: -4700
# Time Step 3, Lane 4, Vehicle Waiting: 74, Green Time Chosen: 15 seconds, Vehicle Left: 59, Reward: -5900
# Time Step 4, Lane 1, Vehicle Waiting: 4, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -2800
# Time Step 4, Lane 2, Vehicle Waiting: 47, Green Time Chosen: 27 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 4, Lane 4, Vehicle Waiting: 59, Green Time Chosen: 3 seconds, Vehicle Left: 56, Reward: -5600
# Time Step 5, Lane 2, Vehicle Waiting: 20, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -200
# Time Step 5, Lane 4, Vehicle Waiting: 56, Green Time Chosen: 18 seconds, Vehicle Left: 38, Reward: -3800
# Time Step 6, Lane 4, Vehicle Waiting: 38, Green Time Chosen: 3 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 7, Lane 4, Vehicle Waiting: 35, Green Time Chosen: 27 seconds, Vehicle Left: 8, Reward: -800
# Time Step 8, Lane 4, Vehicle Waiting: 8, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4400
# Episode 3/500, Epsilon: 0.99
#
# Training Episode 4/500
# Time Step 1, Lane 1, Vehicle Waiting: 65, Green Time Chosen: 24 seconds, Vehicle Left: 41, Reward: -4100
# Time Step 1, Lane 2, Vehicle Waiting: 95, Green Time Chosen: 6 seconds, Vehicle Left: 89, Reward: -8900
# Time Step 1, Lane 3, Vehicle Waiting: 9, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -3000
# Time Step 1, Lane 4, Vehicle Waiting: 67, Green Time Chosen: 18 seconds, Vehicle Left: 49, Reward: -4900
# Time Step 2, Lane 1, Vehicle Waiting: 41, Green Time Chosen: 18 seconds, Vehicle Left: 23, Reward: -2300
# Time Step 2, Lane 2, Vehicle Waiting: 89, Green Time Chosen: 24 seconds, Vehicle Left: 65, Reward: -6500
# Time Step 2, Lane 4, Vehicle Waiting: 49, Green Time Chosen: 9 seconds, Vehicle Left: 40, Reward: -4000
# Time Step 3, Lane 1, Vehicle Waiting: 23, Green Time Chosen: 3 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 3, Lane 2, Vehicle Waiting: 65, Green Time Chosen: 30 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 3, Lane 4, Vehicle Waiting: 40, Green Time Chosen: 27 seconds, Vehicle Left: 13, Reward: -1300
# Time Step 4, Lane 1, Vehicle Waiting: 20, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -200
# Time Step 4, Lane 2, Vehicle Waiting: 35, Green Time Chosen: 12 seconds, Vehicle Left: 23, Reward: -2300
# Time Step 4, Lane 4, Vehicle Waiting: 13, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -400
# Time Step 5, Lane 2, Vehicle Waiting: 23, Green Time Chosen: 6 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 6, Lane 2, Vehicle Waiting: 17, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -200
# Episode 4/500, Epsilon: 0.99
#
# Training Episode 5/500
# Time Step 1, Lane 1, Vehicle Waiting: 73, Green Time Chosen: 21 seconds, Vehicle Left: 52, Reward: -5200
# Time Step 1, Lane 2, Vehicle Waiting: 94, Green Time Chosen: 15 seconds, Vehicle Left: 79, Reward: -7900
# Time Step 1, Lane 3, Vehicle Waiting: 2, Green Time Chosen: 9 seconds, Vehicle Left: 0, Reward: -1400
# Time Step 1, Lane 4, Vehicle Waiting: 78, Green Time Chosen: 18 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 2, Lane 1, Vehicle Waiting: 52, Green Time Chosen: 18 seconds, Vehicle Left: 34, Reward: -3400
# Time Step 2, Lane 2, Vehicle Waiting: 79, Green Time Chosen: 3 seconds, Vehicle Left: 76, Reward: -7600
# Time Step 2, Lane 4, Vehicle Waiting: 60, Green Time Chosen: 3 seconds, Vehicle Left: 57, Reward: -5700
# Time Step 3, Lane 1, Vehicle Waiting: 34, Green Time Chosen: 27 seconds, Vehicle Left: 7, Reward: -700
# Time Step 3, Lane 2, Vehicle Waiting: 76, Green Time Chosen: 21 seconds, Vehicle Left: 55, Reward: -5500
# Time Step 3, Lane 4, Vehicle Waiting: 57, Green Time Chosen: 12 seconds, Vehicle Left: 45, Reward: -4500
# Time Step 4, Lane 1, Vehicle Waiting: 7, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -2200
# Time Step 4, Lane 2, Vehicle Waiting: 55, Green Time Chosen: 15 seconds, Vehicle Left: 40, Reward: -4000
# Time Step 4, Lane 4, Vehicle Waiting: 45, Green Time Chosen: 9 seconds, Vehicle Left: 36, Reward: -3600
# Time Step 5, Lane 2, Vehicle Waiting: 40, Green Time Chosen: 24 seconds, Vehicle Left: 16, Reward: -1600
# Time Step 5, Lane 4, Vehicle Waiting: 36, Green Time Chosen: 21 seconds, Vehicle Left: 15, Reward: -1500
# Time Step 6, Lane 2, Vehicle Waiting: 16, Green Time Chosen: 9 seconds, Vehicle Left: 7, Reward: -700
# Time Step 6, Lane 4, Vehicle Waiting: 15, Green Time Chosen: 12 seconds, Vehicle Left: 3, Reward: -300
# Time Step 7, Lane 2, Vehicle Waiting: 7, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4600
# Time Step 7, Lane 4, Vehicle Waiting: 3, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -1800
# Episode 5/500, Epsilon: 0.99
#
# Training Episode 6/500
# Time Step 1, Lane 1, Vehicle Waiting: 15, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -1800
# Time Step 1, Lane 2, Vehicle Waiting: 12, Green Time Chosen: 0 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 1, Lane 3, Vehicle Waiting: 17, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -1400
# Time Step 1, Lane 4, Vehicle Waiting: 81, Green Time Chosen: 21 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 2, Lane 2, Vehicle Waiting: 12, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -600
# Time Step 2, Lane 4, Vehicle Waiting: 60, Green Time Chosen: 12 seconds, Vehicle Left: 48, Reward: -4800
# Time Step 3, Lane 4, Vehicle Waiting: 48, Green Time Chosen: 27 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 4, Lane 4, Vehicle Waiting: 21, Green Time Chosen: 0 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 5, Lane 4, Vehicle Waiting: 21, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -1800
# Episode 6/500, Epsilon: 0.98
#
# Training Episode 7/500
# Time Step 1, Lane 1, Vehicle Waiting: 37, Green Time Chosen: 3 seconds, Vehicle Left: 34, Reward: -3400
# Time Step 1, Lane 2, Vehicle Waiting: 66, Green Time Chosen: 24 seconds, Vehicle Left: 42, Reward: -4200
# Time Step 1, Lane 3, Vehicle Waiting: 29, Green Time Chosen: 27 seconds, Vehicle Left: 2, Reward: -200
# Time Step 1, Lane 4, Vehicle Waiting: 19, Green Time Chosen: 18 seconds, Vehicle Left: 1, Reward: -100
# Time Step 2, Lane 1, Vehicle Waiting: 34, Green Time Chosen: 24 seconds, Vehicle Left: 10, Reward: -1000
# Time Step 2, Lane 2, Vehicle Waiting: 42, Green Time Chosen: 18 seconds, Vehicle Left: 24, Reward: -2400
# Time Step 2, Lane 3, Vehicle Waiting: 2, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5600
# Time Step 2, Lane 4, Vehicle Waiting: 1, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -4600
# Time Step 3, Lane 1, Vehicle Waiting: 10, Green Time Chosen: 0 seconds, Vehicle Left: 10, Reward: -1000
# Time Step 3, Lane 2, Vehicle Waiting: 24, Green Time Chosen: 9 seconds, Vehicle Left: 15, Reward: -1500
# Time Step 4, Lane 1, Vehicle Waiting: 10, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -1600
# Time Step 4, Lane 2, Vehicle Waiting: 15, Green Time Chosen: 3 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 5, Lane 2, Vehicle Waiting: 12, Green Time Chosen: 3 seconds, Vehicle Left: 9, Reward: -900
# Time Step 6, Lane 2, Vehicle Waiting: 9, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -1800
# Episode 7/500, Epsilon: 0.98
#
# Training Episode 8/500
# Time Step 1, Lane 1, Vehicle Waiting: 87, Green Time Chosen: 24 seconds, Vehicle Left: 63, Reward: -6300
# Time Step 1, Lane 2, Vehicle Waiting: 23, Green Time Chosen: 15 seconds, Vehicle Left: 8, Reward: -800
# Time Step 1, Lane 3, Vehicle Waiting: 47, Green Time Chosen: 21 seconds, Vehicle Left: 26, Reward: -2600
# Time Step 1, Lane 4, Vehicle Waiting: 29, Green Time Chosen: 9 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 2, Lane 1, Vehicle Waiting: 63, Green Time Chosen: 27 seconds, Vehicle Left: 36, Reward: -3600
# Time Step 2, Lane 2, Vehicle Waiting: 8, Green Time Chosen: 0 seconds, Vehicle Left: 8, Reward: -800
# Time Step 2, Lane 3, Vehicle Waiting: 26, Green Time Chosen: 12 seconds, Vehicle Left: 14, Reward: -1400
# Time Step 2, Lane 4, Vehicle Waiting: 20, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -800
# Time Step 3, Lane 1, Vehicle Waiting: 36, Green Time Chosen: 15 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 3, Lane 2, Vehicle Waiting: 8, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -2000
# Time Step 3, Lane 3, Vehicle Waiting: 14, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -200
# Time Step 4, Lane 1, Vehicle Waiting: 21, Green Time Chosen: 18 seconds, Vehicle Left: 3, Reward: -300
# Time Step 5, Lane 1, Vehicle Waiting: 3, Green Time Chosen: 6 seconds, Vehicle Left: 0, Reward: -600
# Episode 8/500, Epsilon: 0.97
#
# Training Episode 9/500
# Time Step 1, Lane 1, Vehicle Waiting: 73, Green Time Chosen: 12 seconds, Vehicle Left: 61, Reward: -6100
# Time Step 1, Lane 2, Vehicle Waiting: 83, Green Time Chosen: 27 seconds, Vehicle Left: 56, Reward: -5600
# Time Step 1, Lane 3, Vehicle Waiting: 26, Green Time Chosen: 21 seconds, Vehicle Left: 5, Reward: -500
# Time Step 1, Lane 4, Vehicle Waiting: 29, Green Time Chosen: 18 seconds, Vehicle Left: 11, Reward: -1100
# Time Step 2, Lane 1, Vehicle Waiting: 61, Green Time Chosen: 9 seconds, Vehicle Left: 52, Reward: -5200
# Time Step 2, Lane 2, Vehicle Waiting: 56, Green Time Chosen: 6 seconds, Vehicle Left: 50, Reward: -5000
# Time Step 2, Lane 3, Vehicle Waiting: 5, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -3200
# Time Step 2, Lane 4, Vehicle Waiting: 11, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -2600
# Time Step 3, Lane 1, Vehicle Waiting: 52, Green Time Chosen: 0 seconds, Vehicle Left: 52, Reward: -5200
# Time Step 3, Lane 2, Vehicle Waiting: 50, Green Time Chosen: 18 seconds, Vehicle Left: 32, Reward: -3200
# Time Step 4, Lane 1, Vehicle Waiting: 52, Green Time Chosen: 18 seconds, Vehicle Left: 34, Reward: -3400
# Time Step 4, Lane 2, Vehicle Waiting: 32, Green Time Chosen: 15 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 5, Lane 1, Vehicle Waiting: 34, Green Time Chosen: 3 seconds, Vehicle Left: 31, Reward: -3100
# Time Step 5, Lane 2, Vehicle Waiting: 17, Green Time Chosen: 0 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 6, Lane 1, Vehicle Waiting: 31, Green Time Chosen: 9 seconds, Vehicle Left: 22, Reward: -2200
# Time Step 6, Lane 2, Vehicle Waiting: 17, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -800
# Time Step 7, Lane 1, Vehicle Waiting: 22, Green Time Chosen: 9 seconds, Vehicle Left: 13, Reward: -1300
# Time Step 8, Lane 1, Vehicle Waiting: 13, Green Time Chosen: 6 seconds, Vehicle Left: 7, Reward: -700
# Time Step 9, Lane 1, Vehicle Waiting: 7, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -3400
# Episode 9/500, Epsilon: 0.97
#
# Training Episode 10/500
# Time Step 1, Lane 1, Vehicle Waiting: 89, Green Time Chosen: 12 seconds, Vehicle Left: 77, Reward: -7700
# Time Step 1, Lane 2, Vehicle Waiting: 75, Green Time Chosen: 0 seconds, Vehicle Left: 75, Reward: -7500
# Time Step 1, Lane 3, Vehicle Waiting: 68, Green Time Chosen: 30 seconds, Vehicle Left: 38, Reward: -3800
# Time Step 1, Lane 4, Vehicle Waiting: 20, Green Time Chosen: 18 seconds, Vehicle Left: 2, Reward: -200
# Time Step 2, Lane 1, Vehicle Waiting: 77, Green Time Chosen: 12 seconds, Vehicle Left: 65, Reward: -6500
# Time Step 2, Lane 2, Vehicle Waiting: 75, Green Time Chosen: 18 seconds, Vehicle Left: 57, Reward: -5700
# Time Step 2, Lane 3, Vehicle Waiting: 38, Green Time Chosen: 3 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 2, Lane 4, Vehicle Waiting: 2, Green Time Chosen: 9 seconds, Vehicle Left: 0, Reward: -1400
# Time Step 3, Lane 1, Vehicle Waiting: 65, Green Time Chosen: 6 seconds, Vehicle Left: 59, Reward: -5900
# Time Step 3, Lane 2, Vehicle Waiting: 57, Green Time Chosen: 21 seconds, Vehicle Left: 36, Reward: -3600
# Time Step 3, Lane 3, Vehicle Waiting: 35, Green Time Chosen: 9 seconds, Vehicle Left: 26, Reward: -2600
# Time Step 4, Lane 1, Vehicle Waiting: 59, Green Time Chosen: 18 seconds, Vehicle Left: 41, Reward: -4100
# Time Step 4, Lane 2, Vehicle Waiting: 36, Green Time Chosen: 9 seconds, Vehicle Left: 27, Reward: -2700
# Time Step 4, Lane 3, Vehicle Waiting: 26, Green Time Chosen: 24 seconds, Vehicle Left: 2, Reward: -200
# Time Step 5, Lane 1, Vehicle Waiting: 41, Green Time Chosen: 0 seconds, Vehicle Left: 41, Reward: -4100
# Time Step 5, Lane 2, Vehicle Waiting: 27, Green Time Chosen: 9 seconds, Vehicle Left: 18, Reward: -1800
# Time Step 5, Lane 3, Vehicle Waiting: 2, Green Time Chosen: 3 seconds, Vehicle Left: 0, Reward: -200
# Time Step 6, Lane 1, Vehicle Waiting: 41, Green Time Chosen: 24 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 6, Lane 2, Vehicle Waiting: 18, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 7, Lane 1, Vehicle Waiting: 17, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -800
# Episode 10/500, Epsilon: 0.96
#
# Training Episode 11/500
# Time Step 1, Lane 1, Vehicle Waiting: 45, Green Time Chosen: 12 seconds, Vehicle Left: 33, Reward: -3300
# Time Step 1, Lane 2, Vehicle Waiting: 27, Green Time Chosen: 0 seconds, Vehicle Left: 27, Reward: -2700
# Time Step 1, Lane 3, Vehicle Waiting: 75, Green Time Chosen: 27 seconds, Vehicle Left: 48, Reward: -4800
# Time Step 1, Lane 4, Vehicle Waiting: 31, Green Time Chosen: 0 seconds, Vehicle Left: 31, Reward: -3100
# Time Step 2, Lane 1, Vehicle Waiting: 33, Green Time Chosen: 12 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 2, Lane 2, Vehicle Waiting: 27, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -600
# Time Step 2, Lane 3, Vehicle Waiting: 48, Green Time Chosen: 0 seconds, Vehicle Left: 48, Reward: -4800
# Time Step 2, Lane 4, Vehicle Waiting: 31, Green Time Chosen: 30 seconds, Vehicle Left: 1, Reward: -100
# Time Step 3, Lane 1, Vehicle Waiting: 21, Green Time Chosen: 0 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 3, Lane 3, Vehicle Waiting: 48, Green Time Chosen: 21 seconds, Vehicle Left: 27, Reward: -2700
# Time Step 3, Lane 4, Vehicle Waiting: 1, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -2200
# Time Step 4, Lane 1, Vehicle Waiting: 21, Green Time Chosen: 3 seconds, Vehicle Left: 18, Reward: -1800
# Time Step 4, Lane 3, Vehicle Waiting: 27, Green Time Chosen: 21 seconds, Vehicle Left: 6, Reward: -600
# Time Step 5, Lane 1, Vehicle Waiting: 18, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -1800
# Time Step 5, Lane 3, Vehicle Waiting: 6, Green Time Chosen: 0 seconds, Vehicle Left: 6, Reward: -600
# Time Step 6, Lane 3, Vehicle Waiting: 6, Green Time Chosen: 6 seconds, Vehicle Left: 0, Reward: 10000
# Episode 11/500, Epsilon: 0.96
#
# Training Episode 12/500
# Time Step 1, Lane 1, Vehicle Waiting: 79, Green Time Chosen: 9 seconds, Vehicle Left: 70, Reward: -7000
# Time Step 1, Lane 2, Vehicle Waiting: 42, Green Time Chosen: 30 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 1, Lane 3, Vehicle Waiting: 1, Green Time Chosen: 3 seconds, Vehicle Left: 0, Reward: -400
# Time Step 1, Lane 4, Vehicle Waiting: 73, Green Time Chosen: 0 seconds, Vehicle Left: 73, Reward: -7300
# Time Step 2, Lane 1, Vehicle Waiting: 70, Green Time Chosen: 27 seconds, Vehicle Left: 43, Reward: -4300
# Time Step 2, Lane 2, Vehicle Waiting: 12, Green Time Chosen: 3 seconds, Vehicle Left: 9, Reward: -900
# Time Step 2, Lane 4, Vehicle Waiting: 73, Green Time Chosen: 24 seconds, Vehicle Left: 49, Reward: -4900
# Time Step 3, Lane 1, Vehicle Waiting: 43, Green Time Chosen: 6 seconds, Vehicle Left: 37, Reward: -3700
# Time Step 3, Lane 2, Vehicle Waiting: 9, Green Time Chosen: 6 seconds, Vehicle Left: 3, Reward: -300
# Time Step 3, Lane 4, Vehicle Waiting: 49, Green Time Chosen: 30 seconds, Vehicle Left: 19, Reward: -1900
# Time Step 4, Lane 1, Vehicle Waiting: 37, Green Time Chosen: 9 seconds, Vehicle Left: 28, Reward: -2800
# Time Step 4, Lane 2, Vehicle Waiting: 3, Green Time Chosen: 9 seconds, Vehicle Left: 0, Reward: -1200
# Time Step 4, Lane 4, Vehicle Waiting: 19, Green Time Chosen: 0 seconds, Vehicle Left: 19, Reward: -1900
# Time Step 5, Lane 1, Vehicle Waiting: 28, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -400
# Time Step 5, Lane 4, Vehicle Waiting: 19, Green Time Chosen: 15 seconds, Vehicle Left: 4, Reward: -400
# Time Step 6, Lane 4, Vehicle Waiting: 4, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -1600
# Episode 12/500, Epsilon: 0.95
#
# Training Episode 13/500
# Time Step 1, Lane 1, Vehicle Waiting: 39, Green Time Chosen: 27 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 1, Lane 2, Vehicle Waiting: 95, Green Time Chosen: 30 seconds, Vehicle Left: 65, Reward: -6500
# Time Step 1, Lane 3, Vehicle Waiting: 59, Green Time Chosen: 6 seconds, Vehicle Left: 53, Reward: -5300
# Time Step 1, Lane 4, Vehicle Waiting: 30, Green Time Chosen: 12 seconds, Vehicle Left: 18, Reward: -1800
# Time Step 2, Lane 1, Vehicle Waiting: 12, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -1800
# Time Step 2, Lane 2, Vehicle Waiting: 65, Green Time Chosen: 18 seconds, Vehicle Left: 47, Reward: -4700
# Time Step 2, Lane 3, Vehicle Waiting: 53, Green Time Chosen: 30 seconds, Vehicle Left: 23, Reward: -2300
# Time Step 2, Lane 4, Vehicle Waiting: 18, Green Time Chosen: 9 seconds, Vehicle Left: 9, Reward: -900
# Time Step 3, Lane 2, Vehicle Waiting: 47, Green Time Chosen: 24 seconds, Vehicle Left: 23, Reward: -2300
# Time Step 3, Lane 3, Vehicle Waiting: 23, Green Time Chosen: 18 seconds, Vehicle Left: 5, Reward: -500
# Time Step 3, Lane 4, Vehicle Waiting: 9, Green Time Chosen: 9 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 4, Lane 2, Vehicle Waiting: 23, Green Time Chosen: 0 seconds, Vehicle Left: 23, Reward: -2300
# Time Step 4, Lane 3, Vehicle Waiting: 5, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5000
# Time Step 5, Lane 2, Vehicle Waiting: 23, Green Time Chosen: 6 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 6, Lane 2, Vehicle Waiting: 17, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -200
# Episode 13/500, Epsilon: 0.95
#
# Training Episode 14/500
# Time Step 1, Lane 1, Vehicle Waiting: 7, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -3400
# Time Step 1, Lane 2, Vehicle Waiting: 99, Green Time Chosen: 0 seconds, Vehicle Left: 99, Reward: -9900
# Time Step 1, Lane 3, Vehicle Waiting: 20, Green Time Chosen: 12 seconds, Vehicle Left: 8, Reward: -800
# Time Step 1, Lane 4, Vehicle Waiting: 86, Green Time Chosen: 3 seconds, Vehicle Left: 83, Reward: -8300
# Time Step 2, Lane 2, Vehicle Waiting: 99, Green Time Chosen: 15 seconds, Vehicle Left: 84, Reward: -8400
# Time Step 2, Lane 3, Vehicle Waiting: 8, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -2000
# Time Step 2, Lane 4, Vehicle Waiting: 83, Green Time Chosen: 0 seconds, Vehicle Left: 83, Reward: -8300
# Time Step 3, Lane 2, Vehicle Waiting: 84, Green Time Chosen: 6 seconds, Vehicle Left: 78, Reward: -7800
# Time Step 3, Lane 4, Vehicle Waiting: 83, Green Time Chosen: 3 seconds, Vehicle Left: 80, Reward: -8000
# Time Step 4, Lane 2, Vehicle Waiting: 78, Green Time Chosen: 3 seconds, Vehicle Left: 75, Reward: -7500
# Time Step 4, Lane 4, Vehicle Waiting: 80, Green Time Chosen: 21 seconds, Vehicle Left: 59, Reward: -5900
# Time Step 5, Lane 2, Vehicle Waiting: 75, Green Time Chosen: 15 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 5, Lane 4, Vehicle Waiting: 59, Green Time Chosen: 6 seconds, Vehicle Left: 53, Reward: -5300
# Time Step 6, Lane 2, Vehicle Waiting: 60, Green Time Chosen: 24 seconds, Vehicle Left: 36, Reward: -3600
# Time Step 6, Lane 4, Vehicle Waiting: 53, Green Time Chosen: 12 seconds, Vehicle Left: 41, Reward: -4100
# Time Step 7, Lane 2, Vehicle Waiting: 36, Green Time Chosen: 30 seconds, Vehicle Left: 6, Reward: -600
# Time Step 7, Lane 4, Vehicle Waiting: 41, Green Time Chosen: 24 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 8, Lane 2, Vehicle Waiting: 6, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -2400
# Time Step 8, Lane 4, Vehicle Waiting: 17, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -800
# Episode 14/500, Epsilon: 0.94
#
# Training Episode 15/500
# Time Step 1, Lane 1, Vehicle Waiting: 85, Green Time Chosen: 18 seconds, Vehicle Left: 67, Reward: -6700
# Time Step 1, Lane 2, Vehicle Waiting: 85, Green Time Chosen: 9 seconds, Vehicle Left: 76, Reward: -7600
# Time Step 1, Lane 3, Vehicle Waiting: 78, Green Time Chosen: 24 seconds, Vehicle Left: 54, Reward: -5400
# Time Step 1, Lane 4, Vehicle Waiting: 73, Green Time Chosen: 30 seconds, Vehicle Left: 43, Reward: -4300
# Time Step 2, Lane 1, Vehicle Waiting: 67, Green Time Chosen: 18 seconds, Vehicle Left: 49, Reward: -4900
# Time Step 2, Lane 2, Vehicle Waiting: 76, Green Time Chosen: 21 seconds, Vehicle Left: 55, Reward: -5500
# Time Step 2, Lane 3, Vehicle Waiting: 54, Green Time Chosen: 24 seconds, Vehicle Left: 30, Reward: -3000
# Time Step 2, Lane 4, Vehicle Waiting: 43, Green Time Chosen: 12 seconds, Vehicle Left: 31, Reward: -3100
# Time Step 3, Lane 1, Vehicle Waiting: 49, Green Time Chosen: 6 seconds, Vehicle Left: 43, Reward: -4300
# Time Step 3, Lane 2, Vehicle Waiting: 55, Green Time Chosen: 27 seconds, Vehicle Left: 28, Reward: -2800
# Time Step 3, Lane 3, Vehicle Waiting: 30, Green Time Chosen: 21 seconds, Vehicle Left: 9, Reward: -900
# Time Step 3, Lane 4, Vehicle Waiting: 31, Green Time Chosen: 3 seconds, Vehicle Left: 28, Reward: -2800
# Time Step 4, Lane 1, Vehicle Waiting: 43, Green Time Chosen: 30 seconds, Vehicle Left: 13, Reward: -1300
# Time Step 4, Lane 2, Vehicle Waiting: 28, Green Time Chosen: 0 seconds, Vehicle Left: 28, Reward: -2800
# Time Step 4, Lane 3, Vehicle Waiting: 9, Green Time Chosen: 3 seconds, Vehicle Left: 6, Reward: -600
# Time Step 4, Lane 4, Vehicle Waiting: 28, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -400
# Time Step 5, Lane 1, Vehicle Waiting: 13, Green Time Chosen: 12 seconds, Vehicle Left: 1, Reward: -100
# Time Step 5, Lane 2, Vehicle Waiting: 28, Green Time Chosen: 27 seconds, Vehicle Left: 1, Reward: -100
# Time Step 5, Lane 3, Vehicle Waiting: 6, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -1800
# Time Step 6, Lane 1, Vehicle Waiting: 1, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -4000
# Time Step 6, Lane 2, Vehicle Waiting: 1, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -5200
# Episode 15/500, Epsilon: 0.94
#
# Training Episode 16/500
# Time Step 1, Lane 1, Vehicle Waiting: 73, Green Time Chosen: 18 seconds, Vehicle Left: 55, Reward: -5500
# Time Step 1, Lane 2, Vehicle Waiting: 58, Green Time Chosen: 21 seconds, Vehicle Left: 37, Reward: -3700
# Time Step 1, Lane 3, Vehicle Waiting: 62, Green Time Chosen: 9 seconds, Vehicle Left: 53, Reward: -5300
# Time Step 1, Lane 4, Vehicle Waiting: 25, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -400
# Time Step 2, Lane 1, Vehicle Waiting: 55, Green Time Chosen: 3 seconds, Vehicle Left: 52, Reward: -5200
# Time Step 2, Lane 2, Vehicle Waiting: 37, Green Time Chosen: 15 seconds, Vehicle Left: 22, Reward: -2200
# Time Step 2, Lane 3, Vehicle Waiting: 53, Green Time Chosen: 27 seconds, Vehicle Left: 26, Reward: -2600
# Time Step 3, Lane 1, Vehicle Waiting: 52, Green Time Chosen: 15 seconds, Vehicle Left: 37, Reward: -3700
# Time Step 3, Lane 2, Vehicle Waiting: 22, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -400
# Time Step 3, Lane 3, Vehicle Waiting: 26, Green Time Chosen: 9 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 4, Lane 1, Vehicle Waiting: 37, Green Time Chosen: 24 seconds, Vehicle Left: 13, Reward: -1300
# Time Step 4, Lane 3, Vehicle Waiting: 17, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -800
# Time Step 5, Lane 1, Vehicle Waiting: 13, Green Time Chosen: 9 seconds, Vehicle Left: 4, Reward: -400
# Time Step 6, Lane 1, Vehicle Waiting: 4, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -4000
# Episode 16/500, Epsilon: 0.93
#
# Training Episode 17/500
# Time Step 1, Lane 1, Vehicle Waiting: 24, Green Time Chosen: 3 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 1, Lane 2, Vehicle Waiting: 20, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -800
# Time Step 1, Lane 3, Vehicle Waiting: 47, Green Time Chosen: 9 seconds, Vehicle Left: 38, Reward: -3800
# Time Step 1, Lane 4, Vehicle Waiting: 53, Green Time Chosen: 27 seconds, Vehicle Left: 26, Reward: -2600
# Time Step 2, Lane 1, Vehicle Waiting: 21, Green Time Chosen: 9 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 2, Lane 3, Vehicle Waiting: 38, Green Time Chosen: 27 seconds, Vehicle Left: 11, Reward: -1100
# Time Step 2, Lane 4, Vehicle Waiting: 26, Green Time Chosen: 0 seconds, Vehicle Left: 26, Reward: -2600
# Time Step 3, Lane 1, Vehicle Waiting: 12, Green Time Chosen: 9 seconds, Vehicle Left: 3, Reward: -300
# Time Step 3, Lane 3, Vehicle Waiting: 11, Green Time Chosen: 6 seconds, Vehicle Left: 5, Reward: -500
# Time Step 3, Lane 4, Vehicle Waiting: 26, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -800
# Time Step 4, Lane 1, Vehicle Waiting: 3, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -4800
# Time Step 4, Lane 3, Vehicle Waiting: 5, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -3800
# Episode 17/500, Epsilon: 0.93
#
# Training Episode 18/500
# Time Step 1, Lane 1, Vehicle Waiting: 77, Green Time Chosen: 27 seconds, Vehicle Left: 50, Reward: -5000
# Time Step 1, Lane 2, Vehicle Waiting: 51, Green Time Chosen: 15 seconds, Vehicle Left: 36, Reward: -3600
# Time Step 1, Lane 3, Vehicle Waiting: 65, Green Time Chosen: 27 seconds, Vehicle Left: 38, Reward: -3800
# Time Step 1, Lane 4, Vehicle Waiting: 15, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3000
# Time Step 2, Lane 1, Vehicle Waiting: 50, Green Time Chosen: 27 seconds, Vehicle Left: 23, Reward: -2300
# Time Step 2, Lane 2, Vehicle Waiting: 36, Green Time Chosen: 27 seconds, Vehicle Left: 9, Reward: -900
# Time Step 2, Lane 3, Vehicle Waiting: 38, Green Time Chosen: 3 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 3, Lane 1, Vehicle Waiting: 23, Green Time Chosen: 3 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 3, Lane 2, Vehicle Waiting: 9, Green Time Chosen: 0 seconds, Vehicle Left: 9, Reward: -900
# Time Step 3, Lane 3, Vehicle Waiting: 35, Green Time Chosen: 0 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 4, Lane 1, Vehicle Waiting: 20, Green Time Chosen: 0 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 4, Lane 2, Vehicle Waiting: 9, Green Time Chosen: 3 seconds, Vehicle Left: 6, Reward: -600
# Time Step 4, Lane 3, Vehicle Waiting: 35, Green Time Chosen: 18 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 5, Lane 1, Vehicle Waiting: 20, Green Time Chosen: 12 seconds, Vehicle Left: 8, Reward: -800
# Time Step 5, Lane 2, Vehicle Waiting: 6, Green Time Chosen: 3 seconds, Vehicle Left: 3, Reward: -300
# Time Step 5, Lane 3, Vehicle Waiting: 17, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -2600
# Time Step 6, Lane 1, Vehicle Waiting: 8, Green Time Chosen: 6 seconds, Vehicle Left: 2, Reward: -200
# Time Step 6, Lane 2, Vehicle Waiting: 3, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -4800
# Time Step 7, Lane 1, Vehicle Waiting: 2, Green Time Chosen: 0 seconds, Vehicle Left: 2, Reward: -200
# Time Step 8, Lane 1, Vehicle Waiting: 2, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -2600
# Episode 18/500, Epsilon: 0.92
#
# Training Episode 19/500
# Time Step 1, Lane 1, Vehicle Waiting: 45, Green Time Chosen: 0 seconds, Vehicle Left: 45, Reward: -4500
# Time Step 1, Lane 2, Vehicle Waiting: 15, Green Time Chosen: 6 seconds, Vehicle Left: 9, Reward: -900
# Time Step 1, Lane 3, Vehicle Waiting: 65, Green Time Chosen: 21 seconds, Vehicle Left: 44, Reward: -4400
# Time Step 1, Lane 4, Vehicle Waiting: 12, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 2, Lane 1, Vehicle Waiting: 45, Green Time Chosen: 27 seconds, Vehicle Left: 18, Reward: -1800
# Time Step 2, Lane 2, Vehicle Waiting: 9, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -600
# Time Step 2, Lane 3, Vehicle Waiting: 44, Green Time Chosen: 12 seconds, Vehicle Left: 32, Reward: -3200
# Time Step 3, Lane 1, Vehicle Waiting: 18, Green Time Chosen: 9 seconds, Vehicle Left: 9, Reward: -900
# Time Step 3, Lane 3, Vehicle Waiting: 32, Green Time Chosen: 0 seconds, Vehicle Left: 32, Reward: -3200
# Time Step 4, Lane 1, Vehicle Waiting: 9, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -3000
# Time Step 4, Lane 3, Vehicle Waiting: 32, Green Time Chosen: 15 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 5, Lane 3, Vehicle Waiting: 17, Green Time Chosen: 6 seconds, Vehicle Left: 11, Reward: -1100
# Time Step 6, Lane 3, Vehicle Waiting: 11, Green Time Chosen: 9 seconds, Vehicle Left: 2, Reward: -200
# Time Step 7, Lane 3, Vehicle Waiting: 2, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -3800
# Episode 19/500, Epsilon: 0.92
#
# Training Episode 20/500
# Time Step 1, Lane 1, Vehicle Waiting: 96, Green Time Chosen: 12 seconds, Vehicle Left: 84, Reward: -8400
# Time Step 1, Lane 2, Vehicle Waiting: 51, Green Time Chosen: 6 seconds, Vehicle Left: 45, Reward: -4500
# Time Step 1, Lane 3, Vehicle Waiting: 30, Green Time Chosen: 24 seconds, Vehicle Left: 6, Reward: -600
# Time Step 1, Lane 4, Vehicle Waiting: 12, Green Time Chosen: 3 seconds, Vehicle Left: 9, Reward: -900
# Time Step 2, Lane 1, Vehicle Waiting: 84, Green Time Chosen: 6 seconds, Vehicle Left: 78, Reward: -7800
# Time Step 2, Lane 2, Vehicle Waiting: 45, Green Time Chosen: 6 seconds, Vehicle Left: 39, Reward: -3900
# Time Step 2, Lane 3, Vehicle Waiting: 6, Green Time Chosen: 6 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 2, Lane 4, Vehicle Waiting: 9, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -3600
# Time Step 3, Lane 1, Vehicle Waiting: 78, Green Time Chosen: 9 seconds, Vehicle Left: 69, Reward: -6900
# Time Step 3, Lane 2, Vehicle Waiting: 39, Green Time Chosen: 12 seconds, Vehicle Left: 27, Reward: -2700
# Time Step 4, Lane 1, Vehicle Waiting: 69, Green Time Chosen: 27 seconds, Vehicle Left: 42, Reward: -4200
# Time Step 4, Lane 2, Vehicle Waiting: 27, Green Time Chosen: 21 seconds, Vehicle Left: 6, Reward: -600
# Time Step 5, Lane 1, Vehicle Waiting: 42, Green Time Chosen: 18 seconds, Vehicle Left: 24, Reward: -2400
# Time Step 5, Lane 2, Vehicle Waiting: 6, Green Time Chosen: 9 seconds, Vehicle Left: 0, Reward: -600
# Time Step 6, Lane 1, Vehicle Waiting: 24, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -1200
# Episode 20/500, Epsilon: 0.91
#
# Training Episode 21/500
# Time Step 1, Lane 1, Vehicle Waiting: 30, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 1, Lane 2, Vehicle Waiting: 8, Green Time Chosen: 3 seconds, Vehicle Left: 5, Reward: -500
# Time Step 1, Lane 3, Vehicle Waiting: 17, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -800
# Time Step 1, Lane 4, Vehicle Waiting: 16, Green Time Chosen: 3 seconds, Vehicle Left: 13, Reward: -1300
# Time Step 2, Lane 2, Vehicle Waiting: 5, Green Time Chosen: 6 seconds, Vehicle Left: 0, Reward: -200
# Time Step 2, Lane 4, Vehicle Waiting: 13, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -400
# Episode 21/500, Epsilon: 0.91
#
# Training Episode 22/500
# Time Step 1, Lane 1, Vehicle Waiting: 83, Green Time Chosen: 24 seconds, Vehicle Left: 59, Reward: -5900
# Time Step 1, Lane 2, Vehicle Waiting: 97, Green Time Chosen: 9 seconds, Vehicle Left: 88, Reward: -8800
# Time Step 1, Lane 3, Vehicle Waiting: 14, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -800
# Time Step 1, Lane 4, Vehicle Waiting: 53, Green Time Chosen: 6 seconds, Vehicle Left: 47, Reward: -4700
# Time Step 2, Lane 1, Vehicle Waiting: 59, Green Time Chosen: 3 seconds, Vehicle Left: 56, Reward: -5600
# Time Step 2, Lane 2, Vehicle Waiting: 88, Green Time Chosen: 21 seconds, Vehicle Left: 67, Reward: -6700
# Time Step 2, Lane 4, Vehicle Waiting: 47, Green Time Chosen: 3 seconds, Vehicle Left: 44, Reward: -4400
# Time Step 3, Lane 1, Vehicle Waiting: 56, Green Time Chosen: 3 seconds, Vehicle Left: 53, Reward: -5300
# Time Step 3, Lane 2, Vehicle Waiting: 67, Green Time Chosen: 27 seconds, Vehicle Left: 40, Reward: -4000
# Time Step 3, Lane 4, Vehicle Waiting: 44, Green Time Chosen: 12 seconds, Vehicle Left: 32, Reward: -3200
# Time Step 4, Lane 1, Vehicle Waiting: 53, Green Time Chosen: 12 seconds, Vehicle Left: 41, Reward: -4100
# Time Step 4, Lane 2, Vehicle Waiting: 40, Green Time Chosen: 24 seconds, Vehicle Left: 16, Reward: -1600
# Time Step 4, Lane 4, Vehicle Waiting: 32, Green Time Chosen: 15 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 5, Lane 1, Vehicle Waiting: 41, Green Time Chosen: 30 seconds, Vehicle Left: 11, Reward: -1100
# Time Step 5, Lane 2, Vehicle Waiting: 16, Green Time Chosen: 15 seconds, Vehicle Left: 1, Reward: -100
# Time Step 5, Lane 4, Vehicle Waiting: 17, Green Time Chosen: 12 seconds, Vehicle Left: 5, Reward: -500
# Time Step 6, Lane 1, Vehicle Waiting: 11, Green Time Chosen: 9 seconds, Vehicle Left: 2, Reward: -200
# Time Step 6, Lane 2, Vehicle Waiting: 1, Green Time Chosen: 6 seconds, Vehicle Left: 0, Reward: -1000
# Time Step 6, Lane 4, Vehicle Waiting: 5, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -3200
# Time Step 7, Lane 1, Vehicle Waiting: 2, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -2000
# Episode 22/500, Epsilon: 0.90
#
# Training Episode 23/500
# Time Step 1, Lane 1, Vehicle Waiting: 90, Green Time Chosen: 27 seconds, Vehicle Left: 63, Reward: -6300
# Time Step 1, Lane 2, Vehicle Waiting: 66, Green Time Chosen: 12 seconds, Vehicle Left: 54, Reward: -5400
# Time Step 1, Lane 3, Vehicle Waiting: 12, Green Time Chosen: 0 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 1, Lane 4, Vehicle Waiting: 23, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -800
# Time Step 2, Lane 1, Vehicle Waiting: 63, Green Time Chosen: 6 seconds, Vehicle Left: 57, Reward: -5700
# Time Step 2, Lane 2, Vehicle Waiting: 54, Green Time Chosen: 9 seconds, Vehicle Left: 45, Reward: -4500
# Time Step 2, Lane 3, Vehicle Waiting: 12, Green Time Chosen: 6 seconds, Vehicle Left: 6, Reward: -600
# Time Step 3, Lane 1, Vehicle Waiting: 57, Green Time Chosen: 6 seconds, Vehicle Left: 51, Reward: -5100
# Time Step 3, Lane 2, Vehicle Waiting: 45, Green Time Chosen: 12 seconds, Vehicle Left: 33, Reward: -3300
# Time Step 3, Lane 3, Vehicle Waiting: 6, Green Time Chosen: 0 seconds, Vehicle Left: 6, Reward: -600
# Time Step 4, Lane 1, Vehicle Waiting: 51, Green Time Chosen: 6 seconds, Vehicle Left: 45, Reward: -4500
# Time Step 4, Lane 2, Vehicle Waiting: 33, Green Time Chosen: 24 seconds, Vehicle Left: 9, Reward: -900
# Time Step 4, Lane 3, Vehicle Waiting: 6, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -3000
# Time Step 5, Lane 1, Vehicle Waiting: 45, Green Time Chosen: 6 seconds, Vehicle Left: 39, Reward: -3900
# Time Step 5, Lane 2, Vehicle Waiting: 9, Green Time Chosen: 3 seconds, Vehicle Left: 6, Reward: -600
# Time Step 6, Lane 1, Vehicle Waiting: 39, Green Time Chosen: 0 seconds, Vehicle Left: 39, Reward: -3900
# Time Step 6, Lane 2, Vehicle Waiting: 6, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -3000
# Time Step 7, Lane 1, Vehicle Waiting: 39, Green Time Chosen: 24 seconds, Vehicle Left: 15, Reward: -1500
# Time Step 8, Lane 1, Vehicle Waiting: 15, Green Time Chosen: 0 seconds, Vehicle Left: 15, Reward: -1500
# Time Step 9, Lane 1, Vehicle Waiting: 15, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -2400
# Episode 23/500, Epsilon: 0.90
#
# Training Episode 24/500
# Time Step 1, Lane 1, Vehicle Waiting: 2, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -2000
# Time Step 1, Lane 2, Vehicle Waiting: 52, Green Time Chosen: 15 seconds, Vehicle Left: 37, Reward: -3700
# Time Step 1, Lane 3, Vehicle Waiting: 49, Green Time Chosen: 27 seconds, Vehicle Left: 22, Reward: -2200
# Time Step 1, Lane 4, Vehicle Waiting: 85, Green Time Chosen: 15 seconds, Vehicle Left: 70, Reward: -7000
# Time Step 2, Lane 2, Vehicle Waiting: 37, Green Time Chosen: 18 seconds, Vehicle Left: 19, Reward: -1900
# Time Step 2, Lane 3, Vehicle Waiting: 22, Green Time Chosen: 0 seconds, Vehicle Left: 22, Reward: -2200
# Time Step 2, Lane 4, Vehicle Waiting: 70, Green Time Chosen: 27 seconds, Vehicle Left: 43, Reward: -4300
# Time Step 3, Lane 2, Vehicle Waiting: 19, Green Time Chosen: 12 seconds, Vehicle Left: 7, Reward: -700
# Time Step 3, Lane 3, Vehicle Waiting: 22, Green Time Chosen: 6 seconds, Vehicle Left: 16, Reward: -1600
# Time Step 3, Lane 4, Vehicle Waiting: 43, Green Time Chosen: 6 seconds, Vehicle Left: 37, Reward: -3700
# Time Step 4, Lane 2, Vehicle Waiting: 7, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -1600
# Time Step 4, Lane 3, Vehicle Waiting: 16, Green Time Chosen: 15 seconds, Vehicle Left: 1, Reward: -100
# Time Step 4, Lane 4, Vehicle Waiting: 37, Green Time Chosen: 3 seconds, Vehicle Left: 34, Reward: -3400
# Time Step 5, Lane 3, Vehicle Waiting: 1, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -3400
# Time Step 5, Lane 4, Vehicle Waiting: 34, Green Time Chosen: 30 seconds, Vehicle Left: 4, Reward: -400
# Time Step 6, Lane 4, Vehicle Waiting: 4, Green Time Chosen: 3 seconds, Vehicle Left: 1, Reward: -100
# Time Step 7, Lane 4, Vehicle Waiting: 1, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -5200
# Episode 24/500, Epsilon: 0.90
#
# Training Episode 25/500
# Time Step 1, Lane 1, Vehicle Waiting: 9, Green Time Chosen: 9 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 1, Lane 2, Vehicle Waiting: 10, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -400
# Time Step 1, Lane 3, Vehicle Waiting: 61, Green Time Chosen: 9 seconds, Vehicle Left: 52, Reward: -5200
# Time Step 1, Lane 4, Vehicle Waiting: 1, Green Time Chosen: 9 seconds, Vehicle Left: 0, Reward: -1600
# Time Step 2, Lane 3, Vehicle Waiting: 52, Green Time Chosen: 6 seconds, Vehicle Left: 46, Reward: -4600
# Time Step 3, Lane 3, Vehicle Waiting: 46, Green Time Chosen: 18 seconds, Vehicle Left: 28, Reward: -2800
# Time Step 4, Lane 3, Vehicle Waiting: 28, Green Time Chosen: 9 seconds, Vehicle Left: 19, Reward: -1900
# Time Step 5, Lane 3, Vehicle Waiting: 19, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -400
# Episode 25/500, Epsilon: 0.89
#
# Training Episode 26/500
# Time Step 1, Lane 1, Vehicle Waiting: 53, Green Time Chosen: 9 seconds, Vehicle Left: 44, Reward: -4400
# Time Step 1, Lane 2, Vehicle Waiting: 7, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -4000
# Time Step 1, Lane 3, Vehicle Waiting: 80, Green Time Chosen: 9 seconds, Vehicle Left: 71, Reward: -7100
# Time Step 1, Lane 4, Vehicle Waiting: 63, Green Time Chosen: 0 seconds, Vehicle Left: 63, Reward: -6300
# Time Step 2, Lane 1, Vehicle Waiting: 44, Green Time Chosen: 27 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 2, Lane 3, Vehicle Waiting: 71, Green Time Chosen: 18 seconds, Vehicle Left: 53, Reward: -5300
# Time Step 2, Lane 4, Vehicle Waiting: 63, Green Time Chosen: 3 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 3, Lane 1, Vehicle Waiting: 17, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -200
# Time Step 3, Lane 3, Vehicle Waiting: 53, Green Time Chosen: 12 seconds, Vehicle Left: 41, Reward: -4100
# Time Step 3, Lane 4, Vehicle Waiting: 60, Green Time Chosen: 27 seconds, Vehicle Left: 33, Reward: -3300
# Time Step 4, Lane 3, Vehicle Waiting: 41, Green Time Chosen: 21 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 4, Lane 4, Vehicle Waiting: 33, Green Time Chosen: 9 seconds, Vehicle Left: 24, Reward: -2400
# Time Step 5, Lane 3, Vehicle Waiting: 20, Green Time Chosen: 15 seconds, Vehicle Left: 5, Reward: -500
# Time Step 5, Lane 4, Vehicle Waiting: 24, Green Time Chosen: 18 seconds, Vehicle Left: 6, Reward: -600
# Time Step 6, Lane 3, Vehicle Waiting: 5, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -3800
# Time Step 6, Lane 4, Vehicle Waiting: 6, Green Time Chosen: 12 seconds, Vehicle Left: 0, Reward: -1200
# Episode 26/500, Epsilon: 0.89
#
# Training Episode 27/500
# Time Step 1, Lane 1, Vehicle Waiting: 48, Green Time Chosen: 3 seconds, Vehicle Left: 45, Reward: -4500
# Time Step 1, Lane 2, Vehicle Waiting: 89, Green Time Chosen: 18 seconds, Vehicle Left: 71, Reward: -7100
# Time Step 1, Lane 3, Vehicle Waiting: 84, Green Time Chosen: 24 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 1, Lane 4, Vehicle Waiting: 84, Green Time Chosen: 3 seconds, Vehicle Left: 81, Reward: -8100
# Time Step 2, Lane 1, Vehicle Waiting: 45, Green Time Chosen: 24 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 2, Lane 2, Vehicle Waiting: 71, Green Time Chosen: 24 seconds, Vehicle Left: 47, Reward: -4700
# Time Step 2, Lane 3, Vehicle Waiting: 60, Green Time Chosen: 12 seconds, Vehicle Left: 48, Reward: -4800
# Time Step 2, Lane 4, Vehicle Waiting: 81, Green Time Chosen: 6 seconds, Vehicle Left: 75, Reward: -7500
# Time Step 3, Lane 1, Vehicle Waiting: 21, Green Time Chosen: 3 seconds, Vehicle Left: 18, Reward: -1800
# Time Step 3, Lane 2, Vehicle Waiting: 47, Green Time Chosen: 3 seconds, Vehicle Left: 44, Reward: -4400
# Time Step 3, Lane 3, Vehicle Waiting: 48, Green Time Chosen: 6 seconds, Vehicle Left: 42, Reward: -4200
# Time Step 3, Lane 4, Vehicle Waiting: 75, Green Time Chosen: 15 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 4, Lane 1, Vehicle Waiting: 18, Green Time Chosen: 9 seconds, Vehicle Left: 9, Reward: -900
# Time Step 4, Lane 2, Vehicle Waiting: 44, Green Time Chosen: 21 seconds, Vehicle Left: 23, Reward: -2300
# Time Step 4, Lane 3, Vehicle Waiting: 42, Green Time Chosen: 12 seconds, Vehicle Left: 30, Reward: -3000
# Time Step 4, Lane 4, Vehicle Waiting: 60, Green Time Chosen: 24 seconds, Vehicle Left: 36, Reward: -3600
# Time Step 5, Lane 1, Vehicle Waiting: 9, Green Time Chosen: 24 seconds, Vehicle Left: 0, Reward: -3000
# Time Step 5, Lane 2, Vehicle Waiting: 23, Green Time Chosen: 9 seconds, Vehicle Left: 14, Reward: -1400
# Time Step 5, Lane 3, Vehicle Waiting: 30, Green Time Chosen: 27 seconds, Vehicle Left: 3, Reward: -300
# Time Step 5, Lane 4, Vehicle Waiting: 36, Green Time Chosen: 3 seconds, Vehicle Left: 33, Reward: -3300
# Time Step 6, Lane 2, Vehicle Waiting: 14, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -800
# Time Step 6, Lane 3, Vehicle Waiting: 3, Green Time Chosen: 15 seconds, Vehicle Left: 0, Reward: -2400
# Time Step 6, Lane 4, Vehicle Waiting: 33, Green Time Chosen: 15 seconds, Vehicle Left: 18, Reward: -1800
# Time Step 7, Lane 4, Vehicle Waiting: 18, Green Time Chosen: 6 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 8, Lane 4, Vehicle Waiting: 12, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -3000
# Episode 27/500, Epsilon: 0.88
#
# Training Episode 28/500
# Time Step 1, Lane 1, Vehicle Waiting: 31, Green Time Chosen: 15 seconds, Vehicle Left: 16, Reward: -1600
# Time Step 1, Lane 2, Vehicle Waiting: 3, Green Time Chosen: 21 seconds, Vehicle Left: 0, Reward: -3600
# Time Step 1, Lane 3, Vehicle Waiting: 62, Green Time Chosen: 0 seconds, Vehicle Left: 62, Reward: -6200
# Time Step 1, Lane 4, Vehicle Waiting: 83, Green Time Chosen: 21 seconds, Vehicle Left: 62, Reward: -6200
# Time Step 2, Lane 1, Vehicle Waiting: 16, Green Time Chosen: 15 seconds, Vehicle Left: 1, Reward: -100
# ...
# Time Step 1, Lane 4, Vehicle Waiting: 21, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -1800
# Time Step 2, Lane 1, Vehicle Waiting: 59, Green Time Chosen: 30 seconds, Vehicle Left: 29, Reward: -2900
# Time Step 2, Lane 2, Vehicle Waiting: 3, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5400
# Time Step 2, Lane 3, Vehicle Waiting: 22, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -1600
# Time Step 3, Lane 1, Vehicle Waiting: 29, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -200
# Episode 491/500, Epsilon: 0.09
#
# Training Episode 492/500
# Time Step 1, Lane 1, Vehicle Waiting: 39, Green Time Chosen: 30 seconds, Vehicle Left: 9, Reward: -900
# Time Step 1, Lane 2, Vehicle Waiting: 41, Green Time Chosen: 30 seconds, Vehicle Left: 11, Reward: -1100
# Time Step 1, Lane 3, Vehicle Waiting: 12, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3600
# Time Step 1, Lane 4, Vehicle Waiting: 47, Green Time Chosen: 30 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 2, Lane 1, Vehicle Waiting: 9, Green Time Chosen: 18 seconds, Vehicle Left: 0, Reward: -1800
# Time Step 2, Lane 2, Vehicle Waiting: 11, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3800
# Time Step 2, Lane 4, Vehicle Waiting: 17, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -2600
# Episode 492/500, Epsilon: 0.09
#
# Training Episode 493/500
# Time Step 1, Lane 1, Vehicle Waiting: 91, Green Time Chosen: 30 seconds, Vehicle Left: 61, Reward: -6100
# Time Step 1, Lane 2, Vehicle Waiting: 65, Green Time Chosen: 30 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 1, Lane 3, Vehicle Waiting: 81, Green Time Chosen: 30 seconds, Vehicle Left: 51, Reward: -5100
# Time Step 1, Lane 4, Vehicle Waiting: 97, Green Time Chosen: 30 seconds, Vehicle Left: 67, Reward: -6700
# Time Step 2, Lane 1, Vehicle Waiting: 61, Green Time Chosen: 30 seconds, Vehicle Left: 31, Reward: -3100
# Time Step 2, Lane 2, Vehicle Waiting: 35, Green Time Chosen: 30 seconds, Vehicle Left: 5, Reward: -500
# Time Step 2, Lane 3, Vehicle Waiting: 51, Green Time Chosen: 3 seconds, Vehicle Left: 48, Reward: -4800
# Time Step 2, Lane 4, Vehicle Waiting: 67, Green Time Chosen: 30 seconds, Vehicle Left: 37, Reward: -3700
# Time Step 3, Lane 1, Vehicle Waiting: 31, Green Time Chosen: 30 seconds, Vehicle Left: 1, Reward: -100
# Time Step 3, Lane 2, Vehicle Waiting: 5, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5000
# Time Step 3, Lane 3, Vehicle Waiting: 48, Green Time Chosen: 30 seconds, Vehicle Left: 18, Reward: -1800
# Time Step 3, Lane 4, Vehicle Waiting: 37, Green Time Chosen: 30 seconds, Vehicle Left: 7, Reward: -700
# Time Step 4, Lane 1, Vehicle Waiting: 1, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5800
# Time Step 4, Lane 3, Vehicle Waiting: 18, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -2400
# Time Step 4, Lane 4, Vehicle Waiting: 7, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4600
# Episode 493/500, Epsilon: 0.09
#
# Training Episode 494/500
# Time Step 1, Lane 1, Vehicle Waiting: 91, Green Time Chosen: 30 seconds, Vehicle Left: 61, Reward: -6100
# Time Step 1, Lane 2, Vehicle Waiting: 6, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4800
# Time Step 1, Lane 3, Vehicle Waiting: 46, Green Time Chosen: 30 seconds, Vehicle Left: 16, Reward: -1600
# Time Step 1, Lane 4, Vehicle Waiting: 2, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5600
# Time Step 2, Lane 1, Vehicle Waiting: 61, Green Time Chosen: 30 seconds, Vehicle Left: 31, Reward: -3100
# Time Step 2, Lane 3, Vehicle Waiting: 16, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -2200
# Time Step 3, Lane 1, Vehicle Waiting: 31, Green Time Chosen: 30 seconds, Vehicle Left: 1, Reward: -100
# Time Step 4, Lane 1, Vehicle Waiting: 1, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5800
# Episode 494/500, Epsilon: 0.09
#
# Training Episode 495/500
# Time Step 1, Lane 1, Vehicle Waiting: 50, Green Time Chosen: 30 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 1, Lane 2, Vehicle Waiting: 25, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -1000
# Time Step 1, Lane 3, Vehicle Waiting: 86, Green Time Chosen: 30 seconds, Vehicle Left: 56, Reward: -5600
# Time Step 1, Lane 4, Vehicle Waiting: 11, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3800
# Time Step 2, Lane 1, Vehicle Waiting: 20, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -2000
# Time Step 2, Lane 3, Vehicle Waiting: 56, Green Time Chosen: 30 seconds, Vehicle Left: 26, Reward: -2600
# Time Step 3, Lane 3, Vehicle Waiting: 26, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -800
# Episode 495/500, Epsilon: 0.08
#
# Training Episode 496/500
# Time Step 1, Lane 1, Vehicle Waiting: 99, Green Time Chosen: 30 seconds, Vehicle Left: 69, Reward: -6900
# Time Step 1, Lane 2, Vehicle Waiting: 95, Green Time Chosen: 30 seconds, Vehicle Left: 65, Reward: -6500
# Time Step 1, Lane 3, Vehicle Waiting: 77, Green Time Chosen: 30 seconds, Vehicle Left: 47, Reward: -4700
# Time Step 1, Lane 4, Vehicle Waiting: 77, Green Time Chosen: 30 seconds, Vehicle Left: 47, Reward: -4700
# Time Step 2, Lane 1, Vehicle Waiting: 69, Green Time Chosen: 9 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 2, Lane 2, Vehicle Waiting: 65, Green Time Chosen: 30 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 2, Lane 3, Vehicle Waiting: 47, Green Time Chosen: 30 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 2, Lane 4, Vehicle Waiting: 47, Green Time Chosen: 30 seconds, Vehicle Left: 17, Reward: -1700
# Time Step 3, Lane 1, Vehicle Waiting: 60, Green Time Chosen: 15 seconds, Vehicle Left: 45, Reward: -4500
# Time Step 3, Lane 2, Vehicle Waiting: 35, Green Time Chosen: 30 seconds, Vehicle Left: 5, Reward: -500
# Time Step 3, Lane 3, Vehicle Waiting: 17, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -2600
# Time Step 3, Lane 4, Vehicle Waiting: 17, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -2600
# Time Step 4, Lane 1, Vehicle Waiting: 45, Green Time Chosen: 30 seconds, Vehicle Left: 15, Reward: -1500
# Time Step 4, Lane 2, Vehicle Waiting: 5, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5000
# Time Step 5, Lane 1, Vehicle Waiting: 15, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3000
# Episode 496/500, Epsilon: 0.08
#
# Training Episode 497/500
# Time Step 1, Lane 1, Vehicle Waiting: 68, Green Time Chosen: 30 seconds, Vehicle Left: 38, Reward: -3800
# Time Step 1, Lane 2, Vehicle Waiting: 51, Green Time Chosen: 30 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 1, Lane 3, Vehicle Waiting: 100, Green Time Chosen: 30 seconds, Vehicle Left: 70, Reward: -7000
# Time Step 1, Lane 4, Vehicle Waiting: 34, Green Time Chosen: 30 seconds, Vehicle Left: 4, Reward: -400
# Time Step 2, Lane 1, Vehicle Waiting: 38, Green Time Chosen: 30 seconds, Vehicle Left: 8, Reward: -800
# Time Step 2, Lane 2, Vehicle Waiting: 21, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -1800
# Time Step 2, Lane 3, Vehicle Waiting: 70, Green Time Chosen: 30 seconds, Vehicle Left: 40, Reward: -4000
# Time Step 2, Lane 4, Vehicle Waiting: 4, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5200
# Time Step 3, Lane 1, Vehicle Waiting: 8, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4400
# Time Step 3, Lane 3, Vehicle Waiting: 40, Green Time Chosen: 30 seconds, Vehicle Left: 10, Reward: -1000
# Time Step 4, Lane 3, Vehicle Waiting: 10, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4000
# Episode 497/500, Epsilon: 0.08
#
# Training Episode 498/500
# Time Step 1, Lane 1, Vehicle Waiting: 37, Green Time Chosen: 30 seconds, Vehicle Left: 7, Reward: -700
# Time Step 1, Lane 2, Vehicle Waiting: 60, Green Time Chosen: 30 seconds, Vehicle Left: 30, Reward: -3000
# Time Step 1, Lane 3, Vehicle Waiting: 8, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4400
# Time Step 1, Lane 4, Vehicle Waiting: 78, Green Time Chosen: 6 seconds, Vehicle Left: 72, Reward: -7200
# Time Step 2, Lane 1, Vehicle Waiting: 7, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4600
# Time Step 2, Lane 2, Vehicle Waiting: 30, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 2, Lane 4, Vehicle Waiting: 72, Green Time Chosen: 30 seconds, Vehicle Left: 42, Reward: -4200
# Time Step 3, Lane 4, Vehicle Waiting: 42, Green Time Chosen: 30 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 4, Lane 4, Vehicle Waiting: 12, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3600
# Episode 498/500, Epsilon: 0.08
#
# Training Episode 499/500
# Time Step 1, Lane 1, Vehicle Waiting: 65, Green Time Chosen: 30 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 1, Lane 2, Vehicle Waiting: 37, Green Time Chosen: 30 seconds, Vehicle Left: 7, Reward: -700
# Time Step 1, Lane 3, Vehicle Waiting: 69, Green Time Chosen: 30 seconds, Vehicle Left: 39, Reward: -3900
# Time Step 1, Lane 4, Vehicle Waiting: 73, Green Time Chosen: 30 seconds, Vehicle Left: 43, Reward: -4300
# Time Step 2, Lane 1, Vehicle Waiting: 35, Green Time Chosen: 30 seconds, Vehicle Left: 5, Reward: -500
# Time Step 2, Lane 2, Vehicle Waiting: 7, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4600
# Time Step 2, Lane 3, Vehicle Waiting: 39, Green Time Chosen: 27 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 2, Lane 4, Vehicle Waiting: 43, Green Time Chosen: 30 seconds, Vehicle Left: 13, Reward: -1300
# Time Step 3, Lane 1, Vehicle Waiting: 5, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5000
# Time Step 3, Lane 3, Vehicle Waiting: 12, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3600
# Time Step 3, Lane 4, Vehicle Waiting: 13, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3400
# Episode 499/500, Epsilon: 0.08
#
# Training Episode 500/500
# Time Step 1, Lane 1, Vehicle Waiting: 80, Green Time Chosen: 30 seconds, Vehicle Left: 50, Reward: -5000
# Time Step 1, Lane 2, Vehicle Waiting: 35, Green Time Chosen: 30 seconds, Vehicle Left: 5, Reward: -500
# Time Step 1, Lane 3, Vehicle Waiting: 79, Green Time Chosen: 24 seconds, Vehicle Left: 55, Reward: -5500
# Time Step 1, Lane 4, Vehicle Waiting: 38, Green Time Chosen: 30 seconds, Vehicle Left: 8, Reward: -800
# Time Step 2, Lane 1, Vehicle Waiting: 50, Green Time Chosen: 30 seconds, Vehicle Left: 20, Reward: -2000
# Time Step 2, Lane 2, Vehicle Waiting: 5, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5000
# Time Step 2, Lane 3, Vehicle Waiting: 55, Green Time Chosen: 30 seconds, Vehicle Left: 25, Reward: -2500
# Time Step 2, Lane 4, Vehicle Waiting: 8, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4400
# Time Step 3, Lane 1, Vehicle Waiting: 20, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -2000
# Time Step 3, Lane 3, Vehicle Waiting: 25, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -1000
# Episode 500/500, Epsilon: 0.08
#
# Testing Episode 1/5
# Time Step 1, Lane 1, Vehicle Waiting: 2, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5600
# Time Step 1, Lane 2, Vehicle Waiting: 98, Green Time Chosen: 30 seconds, Vehicle Left: 68, Reward: -6800
# Time Step 1, Lane 3, Vehicle Waiting: 63, Green Time Chosen: 30 seconds, Vehicle Left: 33, Reward: -3300
# Time Step 1, Lane 4, Vehicle Waiting: 61, Green Time Chosen: 30 seconds, Vehicle Left: 31, Reward: -3100
# Time Step 2, Lane 2, Vehicle Waiting: 68, Green Time Chosen: 30 seconds, Vehicle Left: 38, Reward: -3800
# Time Step 2, Lane 3, Vehicle Waiting: 33, Green Time Chosen: 30 seconds, Vehicle Left: 3, Reward: -300
# Time Step 2, Lane 4, Vehicle Waiting: 31, Green Time Chosen: 30 seconds, Vehicle Left: 1, Reward: -100
# Time Step 3, Lane 2, Vehicle Waiting: 38, Green Time Chosen: 30 seconds, Vehicle Left: 8, Reward: -800
# Time Step 3, Lane 3, Vehicle Waiting: 3, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5400
# Time Step 3, Lane 4, Vehicle Waiting: 1, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5800
# Time Step 4, Lane 2, Vehicle Waiting: 8, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4400
#
# Testing Episode 2/5
# Time Step 1, Lane 1, Vehicle Waiting: 31, Green Time Chosen: 30 seconds, Vehicle Left: 1, Reward: -100
# Time Step 1, Lane 2, Vehicle Waiting: 62, Green Time Chosen: 30 seconds, Vehicle Left: 32, Reward: -3200
# Time Step 1, Lane 3, Vehicle Waiting: 90, Green Time Chosen: 30 seconds, Vehicle Left: 60, Reward: -6000
# Time Step 1, Lane 4, Vehicle Waiting: 92, Green Time Chosen: 30 seconds, Vehicle Left: 62, Reward: -6200
# Time Step 2, Lane 1, Vehicle Waiting: 1, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5800
# Time Step 2, Lane 2, Vehicle Waiting: 32, Green Time Chosen: 30 seconds, Vehicle Left: 2, Reward: -200
# Time Step 2, Lane 3, Vehicle Waiting: 60, Green Time Chosen: 30 seconds, Vehicle Left: 30, Reward: -3000
# Time Step 2, Lane 4, Vehicle Waiting: 62, Green Time Chosen: 30 seconds, Vehicle Left: 32, Reward: -3200
# Time Step 3, Lane 2, Vehicle Waiting: 2, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5600
# Time Step 3, Lane 3, Vehicle Waiting: 30, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: 10000
# Time Step 3, Lane 4, Vehicle Waiting: 32, Green Time Chosen: 30 seconds, Vehicle Left: 2, Reward: -200
# Time Step 4, Lane 4, Vehicle Waiting: 2, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5600
#
# Testing Episode 3/5
# Time Step 1, Lane 1, Vehicle Waiting: 51, Green Time Chosen: 30 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 1, Lane 2, Vehicle Waiting: 14, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3200
# Time Step 1, Lane 3, Vehicle Waiting: 13, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3400
# Time Step 1, Lane 4, Vehicle Waiting: 44, Green Time Chosen: 30 seconds, Vehicle Left: 14, Reward: -1400
# Time Step 2, Lane 1, Vehicle Waiting: 21, Green Time Chosen: 9 seconds, Vehicle Left: 12, Reward: -1200
# Time Step 2, Lane 4, Vehicle Waiting: 14, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3200
# Time Step 3, Lane 1, Vehicle Waiting: 12, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3600
#
# Testing Episode 4/5
# Time Step 1, Lane 1, Vehicle Waiting: 71, Green Time Chosen: 30 seconds, Vehicle Left: 41, Reward: -4100
# Time Step 1, Lane 2, Vehicle Waiting: 27, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -600
# Time Step 1, Lane 3, Vehicle Waiting: 55, Green Time Chosen: 30 seconds, Vehicle Left: 25, Reward: -2500
# Time Step 1, Lane 4, Vehicle Waiting: 59, Green Time Chosen: 30 seconds, Vehicle Left: 29, Reward: -2900
# Time Step 2, Lane 1, Vehicle Waiting: 41, Green Time Chosen: 30 seconds, Vehicle Left: 11, Reward: -1100
# Time Step 2, Lane 3, Vehicle Waiting: 25, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -1000
# Time Step 2, Lane 4, Vehicle Waiting: 29, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -200
# Time Step 3, Lane 1, Vehicle Waiting: 11, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3800
#
# Testing Episode 5/5
# Time Step 1, Lane 1, Vehicle Waiting: 37, Green Time Chosen: 30 seconds, Vehicle Left: 7, Reward: -700
# Time Step 1, Lane 2, Vehicle Waiting: 81, Green Time Chosen: 30 seconds, Vehicle Left: 51, Reward: -5100
# Time Step 1, Lane 3, Vehicle Waiting: 95, Green Time Chosen: 30 seconds, Vehicle Left: 65, Reward: -6500
# Time Step 1, Lane 4, Vehicle Waiting: 44, Green Time Chosen: 30 seconds, Vehicle Left: 14, Reward: -1400
# Time Step 2, Lane 1, Vehicle Waiting: 7, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -4600
# Time Step 2, Lane 2, Vehicle Waiting: 51, Green Time Chosen: 30 seconds, Vehicle Left: 21, Reward: -2100
# Time Step 2, Lane 3, Vehicle Waiting: 65, Green Time Chosen: 30 seconds, Vehicle Left: 35, Reward: -3500
# Time Step 2, Lane 4, Vehicle Waiting: 14, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -3200
# Time Step 3, Lane 2, Vehicle Waiting: 21, Green Time Chosen: 27 seconds, Vehicle Left: 0, Reward: -1200
# Time Step 3, Lane 3, Vehicle Waiting: 35, Green Time Chosen: 30 seconds, Vehicle Left: 5, Reward: -500
# Time Step 4, Lane 3, Vehicle Waiting: 5, Green Time Chosen: 30 seconds, Vehicle Left: 0, Reward: -5000
